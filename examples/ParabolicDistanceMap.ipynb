# %%
# Ensure dependencies are installed.
import sys
# !{sys.executable} -m pip install -q itk-parabolicmorphology 'itkwidgets[all]>=1.0a27' pooch

# %%
# %%javascript
# // Ensure loaded if installed after Jupyter has started
# if (typeof window.loadImJoyRPC === "undefined") {
#   location.reload()
# }

# %%
import pooch
import itk
from itkwidgets import view

# %%
image_file = pooch.retrieve(url='https://w3s.link/ipfs/bafybeify6rxyhhl5ppgbwed6lq46zsqdz22lucthb4g5jyyahddk3paska/cthead1-bin.png',
                            known_hash='eaf0844db248ac949988932f626b834f8e995ab4534b3c746314b27e986c9e52')

# %%
cthead1 = itk.imread(image_file)

view(cthead1)
# Out:
# libpng warning: sCAL: invalid unit
# libpng warning: sCAL: invalid unit
# libpng warning: sCAL: invalid unit
#                 <img id="screenshot_imjoy_window_5595c96a-fa45-4be1-bddc-cae938628baf" src=data:image/png;base64,...>
#                 <script type="text/javascript">
#                     var image = document.getElementById("screenshot_imjoy_window_5595c96a-fa45-4be1-bddc-cae938628baf");
#                     image.src = "data:image/png;base64,...";
#                     var viewer = document.getElementById("imjoy_window_5595c96a-fa45-4be1-bddc-cae938628baf");
#                     // Hide the static image if the Viewer is visible
#                     image.style.display = viewer ? "none" : "block";
#                 </script>
# <div id="8e50a61a-1fda-4fa1-bacf-1811013fad01"></div>

# %% [markdown]
# Traditional distance transform. Faster but less accurate.

# %%
distance = itk.signed_maurer_distance_map_image_filter(cthead1)

view(distance)
# Out:
#                 <img id="screenshot_imjoy_window_b4b68cb5-fdea-4012-8000-696d11ad8dac" src=data:image/png;base64,...>
#                 <script type="text/javascript">
#                     var image = document.getElementById("screenshot_imjoy_window_b4b68cb5-fdea-4012-8000-696d11ad8dac");
#                     image.src = "data:image/png;base64,...";
#                     var viewer = document.getElementById("imjoy_window_b4b68cb5-fdea-4012-8000-696d11ad8dac");
#                     // Hide the static image if the Viewer is visible
#                     image.style.display = viewer ? "none" : "block";
#                 </script>
# <div id="9c7dbe19-a8e4-4b1b-a0cd-6e6e55102fbe"></div>

# %%
parabolic_distance = itk.morphological_signed_distance_transform_image_filter(cthead1)

view(parabolic_distance)
# Out:
#                 <img id="screenshot_imjoy_window_26e98cb7-b26f-4ca0-a4f1-948b4e3c9556" src=data:image/png;base64,...>
#                 <script type="text/javascript">
#                     var image = document.getElementById("screenshot_imjoy_window_26e98cb7-b26f-4ca0-a4f1-948b4e3c9556");
#                     image.src = "data:image/png;base64,...";
#                     var viewer = document.getElementById("imjoy_window_26e98cb7-b26f-4ca0-a4f1-948b4e3c9556");
#                     // Hide the static image if the Viewer is visible
#                     image.style.display = viewer ? "none" : "block";
#                 </script>
# <div id="0c7a1877-0d5a-400a-8096-8be00142c384"></div>
